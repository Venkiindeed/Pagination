# %%
# Data
data = [
    {"id":1,"name":"Product A","category":"Electronics","status":"active"},
    {"id":2,"name":"Product B","category":"Clothing","status":"inactive"},
    {"id":3,"name":"Product C","category":"Electronics","status":"active"},
    {"id":4,"name":"Product D","category":"Electronics","status":"inactive"},
    {"id":5,"name":"Product E","category":"Clothing","status":"active"},
    {"id":6,"name":"Product F","category":"Electronics","status":"active"},
    {"id":7,"name":"Product G","category":"Electronics","status":"active"},
    {"id":8,"name":"Product H","category":"Electronics","status":"active"}
]

def paginate(data, page, page_size, filters):

    filtered = []

    # Step 1: Filtering
    for item in data:

        if item["category"] == filters["category"] and item["status"] == filters["status"]:
            filtered.append(item)

    # Step 2: Pagination
    start = (page - 1) * page_size
    end = start + page_size

    return filtered[start:end]


# Inputs
page = 1
page_size = 6
filters = {"category":"Electronics", "status":"active"}

# Call function
result = paginate(data, page, page_size, filters)
for item in result:
    print(item)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 36
#      33 filters = {}
#      35 # Call function
# ---> 36 result = paginate(data, page, page_size, filters)
#      37 for item in result:
#      38     print(item)
#
# Cell In[125], line 20, in paginate(data, page, page_size, filters)
#      17 # Step 1: Filtering
#      18 for item in data:
# ---> 20     if item["category"] == filters["category"] and item["status"] == filters["status"]:
#      21         filtered.append(item)
#      23 # Step 2: Pagination
#
# KeyError: 'category'

# %%
# Data
data = [
    {"id":1,"name":"Product A","category":"Electronics","status":"active"},
    {"id":2,"name":"Product B","category":"Clothing","status":"inactive"},
    {"id":3,"name":"Product C","category":"Electronics","status":"active"},
    {"id":4,"name":"Product D","category":"Electronics","status":"inactive"},
    {"id":5,"name":"Product E","category":"Clothing","status":"active"},
    {"id":6,"name":"Product F","category":"Electronics","status":"active"},
    {"id":7,"name":"Product G","category":"Electronics","status":"active"},
    {"id":8,"name":"Product H","category":"Electronics","status":"active"}
]

def paginate(data, page, page_size, filters):

    filtered = []

    # Step 1: Filtering
    for item in data:

        if item["category"] == filters["category"] and item["status"] == filters["status"]:
            filtered.append(item)

    # Step 2: Pagination
    start = (page - 1) * page_size
    end = start + page_size

    return filtered[start:end]


# Inputs
page = 2
page_size = 2
filters = {"category":"Electronics", "status":"active"}

# Call function
result = paginate(data, page, page_size, filters)
for item in result:
    print(item)
# Out:
# {'id': 6, 'name': 'Product F', 'category': 'Electronics', 'status': 'active'}
# {'id': 7, 'name': 'Product G', 'category': 'Electronics', 'status': 'active'}

# %%
# Data
data = [
    {"id":1,"name":"Product A","category":"Electronics","status":"active"},
    {"id":2,"name":"Product B","category":"Clothing","status":"inactive"},
    {"id":3,"name":"Product C","category":"Electronics","status":"active"},
    {"id":4,"name":"Product D","category":"Electronics","status":"inactive"},
    {"id":5,"name":"Product E","category":"Clothing","status":"active"},
    {"id":6,"name":"Product F","category":"Electronics","status":"active"}
]

def paginate(data, page, page_size, filters, sort_key, order):

    filtered = []

    # Step 1: Filtering
    for item in data:
        if item["category"] == filters["category"] and item["status"] == filters["status"]:
            filtered.append(item)

    # Step 2: Sorting
    if order == "asc":
        filtered.sort(key=lambda x: x[sort_key])
    else:
        filtered.sort(key=lambda x: x[sort_key], reverse=True)

    # Step 3: Pagination
    start = (page - 1) * page_size
    end = start + page_size

    return filtered[start:end]


# Inputs
page = 1
page_size = 3
filters = {"category":"Electronics", "status":"active"}

sort_key = input("Enter key to sort (id/name/category/status): ")
order = input("Enter order (asc/desc): ")

# Function call
result = paginate(data, page, page_size, filters, sort_key, order)

# Output line by line
for item in result:
    print(item)
# Out:
# Enter key to sort (id/name/category/status):  id
# Enter order (asc/desc):  asc
# {'id': 1, 'name': 'Product A', 'category': 'Electronics', 'status': 'active'}
# {'id': 3, 'name': 'Product C', 'category': 'Electronics', 'status': 'active'}
# {'id': 6, 'name': 'Product F', 'category': 'Electronics', 'status': 'active'}

# %%
# Data
data = [
    {"id":1,"name":"Product A","category":"Electronics","status":"active"},
    {"id":2,"name":"Product B","category":"Clothing","status":"inactive"},
    {"id":3,"name":"Product C","category":"Electronics","status":"active"},
    {"id":4,"name":"Product D","category":"Electronics","status":"inactive"},
    {"id":5,"name":"Product E","category":"Clothing","status":"active"},
    {"id":6,"name":"Product F","category":"Electronics","status":"active"},
    {"id":7,"name":"Product G","category":"Electronics","status":"active"},
    {"id":8,"name":"Product H","category":"Electronics","status":"active"}
]

def paginate(data, page, page_size, filters, sort_key, order):

    filtered = []

    # Step 1: Filtering
    for item in data:
        if item["category"] == filters["category"] and item["status"] == filters["status"]:
            filtered.append(item)

    # Step 2: Sorting
    if order == "asc":
        filtered.sort(key=lambda x: x[sort_key])
    else:
        filtered.sort(key=lambda x: x[sort_key], reverse=True)

    # Step 3: Pagination
    start = (page - 1) * page_size
    end = start + page_size

    return filtered[start:end]


# Inputs
page = 1
page_size = 6

filters = {"category":"Electronics", "status":"active"}
sort_key = input("Enter key to sort (id/name/category/status): ")
order = input("Enter order (asc/desc): ")

# Function calling
result = paginate(data, page, page_size, filters, sort_key, order)

for item in result:
    print(item)
# Out:
# Enter key to sort (id/name/category/status):  id
# Enter order (asc/desc):  desc
# {'id': 8, 'name': 'Product H', 'category': 'Electronics', 'status': 'active'}
# {'id': 7, 'name': 'Product G', 'category': 'Electronics', 'status': 'active'}
# {'id': 6, 'name': 'Product F', 'category': 'Electronics', 'status': 'active'}
# {'id': 3, 'name': 'Product C', 'category': 'Electronics', 'status': 'active'}
# {'id': 1, 'name': 'Product A', 'category': 'Electronics', 'status': 'active'}

# %%
data = [
    {"id":1,"name":"Product A","category":"Electronics","status":"active"},
    {"id":2,"name":"Product B","category":"Clothing","status":"inactive"},
    {"id":3,"name":"Product C","category":"Electronics","status":"active"},
    {"id":4,"name":"Product D","category":"Electronics","status":"inactive"},
    {"id":5,"name":"Product E","category":"Clothing","status":"active"},
    {"id":6,"name":"Product F","category":"Electronics","status":"active"},
    {"id":7,"name":"Product G","category":"Electronics","status":"active"},
    {"id":8,"name":"Product H","category":"Electronics","status":"active"}
]

def paginate(data, page, page_size, filters, sort_key, order):

    filtered = []

    for item in data:
        match = True

        for key, value in filters.items():
            if item.get(key) != value:
                match = False
                break

        if match:
            filtered.append(item)
    #Filtering count
    count = len(filtered)
    print("Filtered Count:", count)

    # Sorting
    if order == "asc":
        filtered.sort(key=lambda x: x[sort_key])
    else:
        filtered.sort(key=lambda x: x[sort_key], reverse=True)

    # Step 3: Pagination
    start = (page - 1) * page_size
    end = start + page_size

    return filtered[start:end]


#page,p_size inputs
page = 1
page_size = 6

filters = {"status":"inactive"}

sort_key = input("Enter key to sort (id/name/category/status): ")
order = input("Enter order (asc/desc): ")

# Function calling from top
result = paginate(data, page, page_size, filters, sort_key, order)


for item in result:
    print(item)
# Out:
# Enter key to sort (id/name/category/status):  id
# Enter order (asc/desc):  asc
# Filtered Count: 2
# {'id': 2, 'name': 'Product B', 'category': 'Clothing', 'status': 'inactive'}
# {'id': 4, 'name': 'Product D', 'category': 'Electronics', 'status': 'inactive'}

# %%
data = [
    {"id":1,"name":"Product A","category":"Electronics","status":"active"},
    {"id":2,"name":"Product B","category":"Clothing","status":"inactive"},
    {"id":3,"name":"Product C","category":"Electronics","status":"active"},
    {"id":4,"name":"Product D","category":"Electronics","status":"inactive"},
    {"id":5,"name":"Product E","category":"Clothing","status":"active"},
    {"id":6,"name":"Product F","category":"Electronics","status":"active"},
    {"id":7,"name":"Product G","category":"Electronics","status":"active"},
    {"id":8,"name":"Product H","category":"Electronics","status":"active"}
]

def paginate(data, page, page_size, filters, sort_key, order):

    filtered = []

    for item in data:
        match = True

        for key, value in filters.items():
            if item.get(key) != value:
                match = False
                break

        if match:
            filtered.append(item)
    #Filtering count
    count = len(filtered)
    print("Filtered Count:", count)

    # Sorting
    if order == "asc":
        filtered.sort(key=lambda x: x[sort_key])
    else:
        filtered.sort(key=lambda x: x[sort_key], reverse=True)

    # Step 3: Pagination
    start = (page - 1) * page_size
    end = start + page_size

    return filtered[start:end]


#page,p_size inputs
page = 1
page_size = 6

filters = {}

sort_key = input("Enter key to sort (id/name/category/status): ")
order = input("Enter order (asc/desc): ")

# Function calling from top
result = paginate(data, page, page_size, filters, sort_key, order)


for item in result:
    print(item)
# Out:
# Enter key to sort (id/name/category/status):  id
# Enter order (asc/desc):  asc
# Filtered Count: 8
# {'id': 1, 'name': 'Product A', 'category': 'Electronics', 'status': 'active'}
# {'id': 2, 'name': 'Product B', 'category': 'Clothing', 'status': 'inactive'}
# {'id': 3, 'name': 'Product C', 'category': 'Electronics', 'status': 'active'}
# {'id': 4, 'name': 'Product D', 'category': 'Electronics', 'status': 'inactive'}
# {'id': 5, 'name': 'Product E', 'category': 'Clothing', 'status': 'active'}
# {'id': 6, 'name': 'Product F', 'category': 'Electronics', 'status': 'active'}
